# %% [markdown]
# Germano Costa

# %% [markdown]
# Germano Costa
# Ph.D. Researcher
#
# I am interested in data science because I enjoy being a part of new technologies and trying out innovative solutions,
# which I noticed your company also values. I'm especially interested in artificial intelligence after learning about
# machine learning in my studies, and I'm eager to use AI in a more practical capacity.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
first=[2,4,7,3,1,5,1,0,2,3,6,4]
second=[0,5,3,1,6,4,1,1,3,4,3,2]
firsts=plt.plot(range(1,13),first)
seconds=plt.plot(range(1,13),second)
plt.title("books read by students")
plt.xlabel("months")
plt.ylabel("books read")
plt.legend(["books first","books second"])
plt.show()
